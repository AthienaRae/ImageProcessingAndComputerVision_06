# %% [markdown]
# <a href="https://colab.research.google.com/github/AthienaRae/ImageProcessingAndComputerVision_06/blob/main/AR_Featuring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

img1 = cv2.imread("diffangle1.jpg", 0)
img2 = cv2.imread("diffangle2.jpg", 0)

orb = cv2.ORB_create()

kp1, des1 = orb.detectAndCompute(img1, None)
kp2, des2 = orb.detectAndCompute(img2, None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

matches = bf.match(des1, des2)
matches = sorted(matches, key=lambda x: x.distance)

result = cv2.drawMatches(
    img1, kp1, img2, kp2,
    matches[:30], None,
    flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS
)

cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=252x185>
