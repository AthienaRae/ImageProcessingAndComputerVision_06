# %% [markdown]
# <a href="https://colab.research.google.com/github/AthienaRae/ImageProcessingAndComputerVision_06/blob/main/motion_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

cap = cv2.VideoCapture("t1.mp4")

ret, frame1 = cap.read()
prev = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
prev = cv2.GaussianBlur(prev, (15,15), 0)

while cap.isOpened():
    ret, frame2 = cap.read()
    if not ret:
        break

    gray = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (15,15), 0)

    diff = cv2.absdiff(prev, gray)

    cv2.imshow("Motion Tracking", diff)

    if cv2.waitKey(30) & 0xFF == ord('q'):
        break

    prev = gray

cap.release()
cv2.destroyAllWindows()
