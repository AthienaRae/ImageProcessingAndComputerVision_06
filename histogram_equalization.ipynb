# %%
import cv2, numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("squirl.jpg", 0)

# %%
eq = cv2.equalizeHist(img)

plt.subplot(121), plt.imshow(img, cmap='gray')
plt.title("Original")

plt.subplot(122), plt.imshow(eq, cmap='gray')
plt.title("Equalized")

plt.show()
